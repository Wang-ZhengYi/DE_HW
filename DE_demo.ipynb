# %% [markdown]
# # Dark Energy Assignments

# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib
from DE import *

# %%
class Omg(object):
	m0 = 0.3
	L0 = 0.7
	r0 = 8.4e-5
	k0 = 0
	h  = 0.68 
	H0 = 1/14.38

# %% [markdown]
# ## Cosmological Compositions Dominant Era

# %%
Era()

# %% [markdown]
# # FRLW Universes

# %%
Universes()
# Out:
# /home/wangzhengyi/anaconda3/bin/Wangzhengyi/GitHub/DE_HW/DE.py:130: RuntimeWarning: divide by zero encountered in true_divide
#   OL_1[:]   = 4*Om_1[:]*np.cosh(np.arccosh(1/Om_1[:]-1)/3)**3#m-L in (0,1/2]
# /home/wangzhengyi/anaconda3/bin/Wangzhengyi/GitHub/DE_HW/DE.py:130: RuntimeWarning: invalid value encountered in multiply
#   OL_1[:]   = 4*Om_1[:]*np.cosh(np.arccosh(1/Om_1[:]-1)/3)**3#m-L in (0,1/2]
# findfont: Font family ['Segoe Print'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Segoe Print'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Linear Growth Factor

# %%
plot_Growth()
